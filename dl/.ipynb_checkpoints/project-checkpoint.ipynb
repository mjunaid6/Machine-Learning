# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# -------------------------------
# Scikit-Learn (Machine Learning utilities)
# -------------------------------
from sklearn.model_selection import train_test_split
#  Splits the dataset into training and testing sets to evaluate model performance.

from sklearn.preprocessing import LabelEncoder, StandardScaler
# LabelEncoder: Converts categorical labels (e.g., "cat", "dog") into numeric values.
# StandardScaler: Normalizes/standardizes numerical features so they have mean=0 and variance=1.

from sklearn.linear_model import Perceptron
# A simple linear classifier (single-layer neural network). Good for binary classification tasks.

from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
# accuracy_score: Measures how many predictions are correct.
# classification_report: Shows precision, recall, and F1-score for each class.
# confusion_matrix: Shows where the model is making correct vs wrong predictions.

# -------------------------------
# TensorFlow / Keras (Deep Learning utilities)
# -------------------------------
import tensorflow as tf

from tensorflow.keras.models import Sequential
# Lets you build a neural network layer-by-layer in a linear fashion.

from tensorflow.keras.layers import Dense
# Fully connected layer (every neuron connects to every neuron in the next layer).

from tensorflow.keras.layers import Dropout
# Randomly drops some neurons during training to prevent overfitting.

from tensorflow.keras.utils import to_categorical
# 👉 Converts class labels (like 0, 1, 2) into one-hot encoded format (e.g., [1,0,0], [0,1,0]).

# %%
df = pd.read_csv('iris.data.csv')

# %%
sns.pairplot(df, hue = 'Species')

# %%
df
# Out:
#      SepalLength  SepalWidth  PetalLength  PetalWidth         Species
# 0            5.1         3.5          1.4         0.2     Iris-setosa
# 1            4.9         3.0          1.4         0.2     Iris-setosa
# 2            4.7         3.2          1.3         0.2     Iris-setosa
# 3            4.6         3.1          1.5         0.2     Iris-setosa
# 4            5.0         3.6          1.4         0.2     Iris-setosa
# ..           ...         ...          ...         ...             ...
# 145          6.7         3.0          5.2         2.3  Iris-virginica
# 146          6.3         2.5          5.0         1.9  Iris-virginica
# 147          6.5         3.0          5.2         2.0  Iris-virginica
# 148          6.2         3.4          5.4         2.3  Iris-virginica
# 149          5.9         3.0          5.1         1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
X = df.drop(columns = ['Species'], axis = 1)
y = df['Species']

# %%
encoder = LabelEncoder()
y = encoder.fit_transform(y)

# %%
X_train , X_test, y_train, y_test = train_test_split(X, y, test_size = 0.20, random_state = 42, stratify = y)

# %%
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.fit_transform(X_test)

# %%
perc = Perceptron(max_iter = 1000, random_state = 42)
perc.fit(X_train, y_train)
# Out:
# Perceptron(random_state=42)

# %%
y_pred = perc.predict(X_test)

# %%
acc_sc = accuracy_score(y_test, y_pred)
print("Accuracy : ", acc_sc)
# Out:
# Accuracy :  0.84

# %%
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.89      1.00      0.94        25
#            1       0.71      0.88      0.79        25
#            2       1.00      0.64      0.78        25
#
#     accuracy                           0.84        75
#    macro avg       0.87      0.84      0.84        75
# weighted avg       0.87      0.84      0.84        75

# %%
y_train_cat = to_categorical(y_train, num_classes = 3)
y_test_cat = to_categorical(y_test, num_classes = 3)

# %%
model = Sequential([
    Input(shape = (4,)),
    Dense(48, activation = 'relu'),
    Dense(32, activation = 'relu'),
    Dense(16, activation = 'relu'),
    Dense(8, activation = 'relu'),
    Dense(3, activation = 'softmax')
])

# %%
model.compile(
    optimizer = 'adam',
    loss = 'categorical_crossentropy',
    metrics = ['accuracy']
)

# %%
histroy = model.fit(
    X_train, y_train_cat,
    validation_data = (X_test, y_test_cat),
    epochs = 100,
    batch_size = 16,
    validation_split = 0.2,
    verbose = 1
)
# Out:
# Epoch 1/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 2s 53ms/step - accuracy: 0.3333 - loss: 1.1829 - val_accuracy: 0.3333 - val_loss: 1.1053
# Epoch 2/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.3333 - loss: 1.0929 - val_accuracy: 0.3333 - val_loss: 1.0724
# Epoch 3/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.3333 - loss: 1.0702 - val_accuracy: 0.3333 - val_loss: 1.0524
# Epoch 4/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.3333 - loss: 1.0452 - val_accuracy: 0.3333 - val_loss: 1.0347
# Epoch 5/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.3333 - loss: 1.0277 - val_accuracy: 0.3667 - val_loss: 1.0133
# Epoch 6/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.3917 - loss: 1.0089 - val_accuracy: 0.6000 - val_loss: 0.9919
# Epoch 7/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.5917 - loss: 0.9863 - val_accuracy: 0.6667 - val_loss: 0.9680
# Epoch 8/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.6583 - loss: 0.9583 - val_accuracy: 0.6667 - val_loss: 0.9395
# Epoch 9/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.6583 - loss: 0.9308 - val_accuracy: 0.6667 - val_loss: 0.9099
# Epoch 10/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.6667 - loss: 0.9021 - val_accuracy: 0.6667 - val_loss: 0.8797
# Epoch 11/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.6667 - loss: 0.8691 - val_accuracy: 0.6667 - val_loss: 0.8431
# Epoch 12/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.7333 - loss: 0.8400 - val_accuracy: 0.6667 - val_loss: 0.8066
# Epoch 13/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.6917 - loss: 0.8027 - val_accuracy: 0.9333 - val_loss: 0.7624
# Epoch 14/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.7667 - loss: 0.7559 - val_accuracy: 0.9000 - val_loss: 0.7182
# Epoch 15/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9000 - loss: 0.7107 - val_accuracy: 0.9000 - val_loss: 0.6701
# Epoch 16/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.7917 - loss: 0.6601 - val_accuracy: 0.9000 - val_loss: 0.6263
# Epoch 17/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9500 - loss: 0.6085 - val_accuracy: 0.9667 - val_loss: 0.5787
# Epoch 18/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9083 - loss: 0.5636 - val_accuracy: 0.9333 - val_loss: 0.5229
# Epoch 19/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9250 - loss: 0.5036 - val_accuracy: 0.9000 - val_loss: 0.4731
# Epoch 20/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.9667 - loss: 0.4517 - val_accuracy: 0.9333 - val_loss: 0.4089
# Epoch 21/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.9667 - loss: 0.3960 - val_accuracy: 1.0000 - val_loss: 0.3537
# Epoch 22/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9667 - loss: 0.3323 - val_accuracy: 0.9667 - val_loss: 0.3005
# Epoch 23/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9333 - loss: 0.2950 - val_accuracy: 0.9000 - val_loss: 0.2722
# Epoch 24/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9417 - loss: 0.2483 - val_accuracy: 0.9333 - val_loss: 0.2324
# Epoch 25/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.9583 - loss: 0.2049 - val_accuracy: 1.0000 - val_loss: 0.1863
# Epoch 26/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9750 - loss: 0.1746 - val_accuracy: 1.0000 - val_loss: 0.1693
# Epoch 27/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.9667 - loss: 0.1555 - val_accuracy: 1.0000 - val_loss: 0.1487
# Epoch 28/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.9667 - loss: 0.1460 - val_accuracy: 1.0000 - val_loss: 0.1359
# Epoch 29/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.9667 - loss: 0.1373 - val_accuracy: 1.0000 - val_loss: 0.1263
# Epoch 30/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.9667 - loss: 0.1221 - val_accuracy: 0.9333 - val_loss: 0.1333
# Epoch 31/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.9667 - loss: 0.1140 - val_accuracy: 1.0000 - val_loss: 0.1084
# Epoch 32/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.9583 - loss: 0.1367 - val_accuracy: 0.9667 - val_loss: 0.1190
# Epoch 33/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.9583 - loss: 0.1121 - val_accuracy: 1.0000 - val_loss: 0.1024
# Epoch 34/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9750 - loss: 0.1053 - val_accuracy: 1.0000 - val_loss: 0.0920
# Epoch 35/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.9667 - loss: 0.1047 - val_accuracy: 0.9333 - val_loss: 0.1308
# Epoch 36/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.9500 - loss: 0.1271 - val_accuracy: 1.0000 - val_loss: 0.0850
# Epoch 37/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9667 - loss: 0.1018 - val_accuracy: 1.0000 - val_loss: 0.0914
# Epoch 38/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.9750 - loss: 0.0913 - val_accuracy: 1.0000 - val_loss: 0.0856
# Epoch 39/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.9750 - loss: 0.0891 - val_accuracy: 1.0000 - val_loss: 0.0801
# Epoch 40/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.9667 - loss: 0.0857 - val_accuracy: 1.0000 - val_loss: 0.0786
# Epoch 41/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.9750 - loss: 0.0814 - val_accuracy: 1.0000 - val_loss: 0.0824
# Epoch 42/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.9667 - loss: 0.0849 - val_accuracy: 1.0000 - val_loss: 0.0713
# Epoch 43/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.9500 - loss: 0.0898 - val_accuracy: 0.9667 - val_loss: 0.0832
# Epoch 44/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9667 - loss: 0.0820 - val_accuracy: 1.0000 - val_loss: 0.0683
# Epoch 45/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.9833 - loss: 0.0791 - val_accuracy: 1.0000 - val_loss: 0.0711
# Epoch 46/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.9667 - loss: 0.0820 - val_accuracy: 1.0000 - val_loss: 0.0657
# Epoch 47/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.9667 - loss: 0.0855 - val_accuracy: 0.9667 - val_loss: 0.0862
# Epoch 48/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.9833 - loss: 0.0791 - val_accuracy: 1.0000 - val_loss: 0.0708
# Epoch 49/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.9750 - loss: 0.0760 - val_accuracy: 1.0000 - val_loss: 0.0688
# Epoch 50/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9750 - loss: 0.0758 - val_accuracy: 1.0000 - val_loss: 0.0678
# Epoch 51/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.9750 - loss: 0.0757 - val_accuracy: 1.0000 - val_loss: 0.0663
# Epoch 52/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.9667 - loss: 0.0810 - val_accuracy: 1.0000 - val_loss: 0.0701
# Epoch 53/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.9417 - loss: 0.0815 - val_accuracy: 1.0000 - val_loss: 0.0592
# Epoch 54/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.9583 - loss: 0.0867 - val_accuracy: 1.0000 - val_loss: 0.0672
# Epoch 55/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.9750 - loss: 0.0771 - val_accuracy: 1.0000 - val_loss: 0.0705
# Epoch 56/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.9583 - loss: 0.0912 - val_accuracy: 1.0000 - val_loss: 0.0556
# Epoch 57/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9750 - loss: 0.0759 - val_accuracy: 0.9667 - val_loss: 0.0784
# Epoch 58/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9500 - loss: 0.0977 - val_accuracy: 1.0000 - val_loss: 0.0577
# Epoch 59/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9750 - loss: 0.0717 - val_accuracy: 0.9333 - val_loss: 0.1084
# Epoch 60/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9833 - loss: 0.0744 - val_accuracy: 1.0000 - val_loss: 0.0532
# Epoch 61/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9667 - loss: 0.1098 - val_accuracy: 1.0000 - val_loss: 0.0618
# Epoch 62/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9333 - loss: 0.1298 - val_accuracy: 1.0000 - val_loss: 0.0538
# Epoch 63/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9667 - loss: 0.0890 - val_accuracy: 1.0000 - val_loss: 0.0526
# Epoch 64/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9833 - loss: 0.0618 - val_accuracy: 0.9333 - val_loss: 0.0966
# Epoch 65/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9583 - loss: 0.0859 - val_accuracy: 1.0000 - val_loss: 0.0572
# Epoch 66/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9583 - loss: 0.0851 - val_accuracy: 1.0000 - val_loss: 0.0592
# Epoch 67/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9833 - loss: 0.0756 - val_accuracy: 1.0000 - val_loss: 0.0529
# Epoch 68/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9750 - loss: 0.0777 - val_accuracy: 0.9333 - val_loss: 0.0786
# Epoch 69/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9667 - loss: 0.0700 - val_accuracy: 1.0000 - val_loss: 0.0504
# Epoch 70/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9667 - loss: 0.0756 - val_accuracy: 1.0000 - val_loss: 0.0572
# Epoch 71/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9667 - loss: 0.0669 - val_accuracy: 0.9333 - val_loss: 0.0825
# Epoch 72/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9667 - loss: 0.0861 - val_accuracy: 1.0000 - val_loss: 0.0486
# Epoch 73/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9750 - loss: 0.0627 - val_accuracy: 0.9333 - val_loss: 0.1435
# Epoch 74/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9750 - loss: 0.0778 - val_accuracy: 1.0000 - val_loss: 0.0476
# Epoch 75/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9583 - loss: 0.0817 - val_accuracy: 1.0000 - val_loss: 0.0545
# Epoch 76/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9833 - loss: 0.0715 - val_accuracy: 1.0000 - val_loss: 0.0514
# Epoch 77/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9833 - loss: 0.0646 - val_accuracy: 1.0000 - val_loss: 0.0491
# Epoch 78/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9750 - loss: 0.0683 - val_accuracy: 1.0000 - val_loss: 0.0551
# Epoch 79/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9583 - loss: 0.0700 - val_accuracy: 1.0000 - val_loss: 0.0501
# Epoch 80/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9667 - loss: 0.0685 - val_accuracy: 1.0000 - val_loss: 0.0526
# Epoch 81/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9750 - loss: 0.0655 - val_accuracy: 0.9667 - val_loss: 0.0656
# Epoch 82/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9500 - loss: 0.0908 - val_accuracy: 1.0000 - val_loss: 0.0460
# Epoch 83/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9750 - loss: 0.0712 - val_accuracy: 0.9667 - val_loss: 0.0728
# Epoch 84/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9667 - loss: 0.0760 - val_accuracy: 1.0000 - val_loss: 0.0539
# Epoch 85/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9750 - loss: 0.0714 - val_accuracy: 1.0000 - val_loss: 0.0461
# Epoch 86/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9750 - loss: 0.0664 - val_accuracy: 1.0000 - val_loss: 0.0499
# Epoch 87/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9750 - loss: 0.0695 - val_accuracy: 1.0000 - val_loss: 0.0592
# Epoch 88/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9833 - loss: 0.0647 - val_accuracy: 1.0000 - val_loss: 0.0531
# Epoch 89/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9833 - loss: 0.0626 - val_accuracy: 1.0000 - val_loss: 0.0442
# Epoch 90/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9750 - loss: 0.0639 - val_accuracy: 0.9667 - val_loss: 0.0634
# Epoch 91/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.9750 - loss: 0.0738 - val_accuracy: 1.0000 - val_loss: 0.0443
# Epoch 92/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9833 - loss: 0.0657 - val_accuracy: 0.9667 - val_loss: 0.0655
# Epoch 93/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9833 - loss: 0.0661 - val_accuracy: 1.0000 - val_loss: 0.0536
# Epoch 94/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9583 - loss: 0.0733 - val_accuracy: 1.0000 - val_loss: 0.0463
# Epoch 95/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9750 - loss: 0.0707 - val_accuracy: 1.0000 - val_loss: 0.0563
# Epoch 96/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9833 - loss: 0.0632 - val_accuracy: 1.0000 - val_loss: 0.0500
# Epoch 97/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9667 - loss: 0.0778 - val_accuracy: 1.0000 - val_loss: 0.0567
# Epoch 98/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9750 - loss: 0.0751 - val_accuracy: 1.0000 - val_loss: 0.0461
# Epoch 99/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9833 - loss: 0.0639 - val_accuracy: 0.9333 - val_loss: 0.0792
# Epoch 100/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9500 - loss: 0.0784 - val_accuracy: 1.0000 - val_loss: 0.0461

# %%
plt.figure(figsize = (10,4))
plt.plot(histroy.history['accuracy'], label = 'train_acc')
plt.plot(histroy.history['val_accuracy'], label = 'test_acc')

# %%
loss, acc = model.evaluate(X_test, y_test_cat, verbose = 1)
# Out:
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.8267 - loss: 0.4194
